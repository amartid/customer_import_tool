# %%
import csv
import logging

# Configure logging
logging.basicConfig(filename='import_customer.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read CSV file and return a list of dictionaries
def csv_to_dict_list(file_path):
    try:
        with open(file_path, 'r') as csv_file:
            reader = csv.DictReader(csv_file)
            data = [row for row in reader]
        logging.info('CSV file read successfully.')
        return data
    except Exception as e:
        logging.error(f"Error reading CSV file: {e}")
        return []

# Process each row of data
def process_data(data):
    for row in data:
        try:
            # Process each row of data here
            # For demonstration, just printing the row
            print(row)
            logging.info(f"Processed row: {row}")
        except Exception as e:
            logging.error(f"Error processing row: {row}. Error: {e}")

# Read CSV file and process data
file_path = 'customer_import.csv'
logging.info('Starting data import...')
print('Starting data import...')

csv_data = csv_to_dict_list(file_path)

if csv_data:
    print('CSV file read successfully.')
    logging.info('CSV file read successfully.')
    print('Importing Candidates Information from CSV file...')
    logging.info('Importing Candidates Information from CSV file...')
    process_data(csv_data)
    print('Data import CSV file completed.')
    logging.info('Data import from CSV file completed.')
else:
    print('Error reading CSV file. Please check the log for details.')
    logging.error('Error reading CSV file. Data import aborted.')
# Out:
# Starting data import...
# CSV file read successfully.
# Importing Candidates Information from CSV file...
# {'Candidate Id': '1', 'First Name': 'John', 'Last Name': 'Doe', 'Email': 'john.doe@email.com', 'Phone': '123-456-7890', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '123 Main St', 'Address 2': '', 'City': 'Anytown', 'State': 'CA', 'Country': 'United States', 'Zip': '12345', 'Available Date': '2023-02-01', 'Website Url': 'https://www.johndoe.com', 'Linkedin Url': 'https://www.linkedin.com/in/johndoe', 'Twitter Username': '@johndoe', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'University of Tech', 'Gender': 'Male', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-01-15 09:30:00', 'Desired Salary': '80000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterXYZ', 'Resume File Id': '1', 'Cover Letter File Id': '', 'Resume File': 'John_Doe_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '2', 'First Name': 'Jane', 'Last Name': 'Smith', 'Email': 'jane.smith@email.com', 'Phone': '987-654-3210', 'Position': 'Data Architect', 'Status': 'Interview Scheduled', 'Address': '456 Oak St', 'Address 2': '', 'City': 'Someville', 'State': 'NY', 'Country': 'United States', 'Zip': '56789', 'Available Date': '2023-03-15', 'Website Url': 'https://www.janesmith.com', 'Linkedin Url': 'https://www.linkedin.com/in/janesmith', 'Twitter Username': '@janesmith', 'Education Level': "Master's Degree", 'Education Institution Name': 'Marketing Institute', 'Gender': 'Female', 'Ethnicity': 'Hispanic', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-02-10 11:45:00', 'Desired Salary': '60000', 'Referred By': 'Job board', 'References': 'Previous employer', 'Source': 'RecruiterABC', 'Resume File Id': '2', 'Cover Letter File Id': '3', 'Resume File': 'Jane_Smith_Resume.pdf', 'Cover Letter File': 'Jane_Smith_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '3', 'First Name': 'Michael', 'Last Name': 'Jones', 'Email': 'michael.jones@email.com', 'Phone': '555-123-4567', 'Position': 'Data Architect', 'Status': 'Offer Extended', 'Address': '789 Pine St', 'Address 2': '', 'City': 'Sometown', 'State': 'TX', 'Country': 'United States', 'Zip': '67890', 'Available Date': '2023-04-01', 'Website Url': 'https://www.michaeljones.com', 'Linkedin Url': 'https://www.linkedin.com/in/michaeljones', 'Twitter Username': '@michaeljones', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Data University', 'Gender': 'Male', 'Ethnicity': 'African American', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-03-01 15:00:00', 'Desired Salary': '70000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'CompanyXYZ', 'Resume File Id': '3', 'Cover Letter File Id': '', 'Resume File': 'Michael_Jones_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '4', 'First Name': 'Sarah', 'Last Name': 'Clark', 'Email': 'sarah.clark@email.com', 'Phone': '111-222-3333', 'Position': 'Data Architect', 'Status': 'Rejected', 'Address': '', 'Address 2': '', 'City': 'Metroville', 'State': 'CA', 'Country': 'United States', 'Zip': '54321', 'Available Date': '', 'Website Url': '', 'Linkedin Url': 'https://www.linkedin.com/in/sarahclark', 'Twitter Username': '@sarahclark', 'Education Level': "Master's Degree", 'Education Institution Name': 'HR Institute', 'Gender': 'Female', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2022-11-15 14:20:00', 'Desired Salary': '90000', 'Referred By': 'Job board', 'References': 'Previous colleague', 'Source': 'RecruiterDEF', 'Resume File Id': '4', 'Cover Letter File Id': '5', 'Resume File': 'Sarah_Clark_Resume.pdf', 'Cover Letter File': 'Sarah_Clark_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '5', 'First Name': 'Chris', 'Last Name': 'Nguyen', 'Email': 'chris.nguyen@email.com', 'Phone': '999-888-7777', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '987 Elm St', 'Address 2': '', 'City': 'Cityville', 'State': 'NY', 'Country': 'United States', 'Zip': '45678', 'Available Date': '2023-05-01', 'Website Url': 'https://www.chrisnguyen.com', 'Linkedin Url': 'https://www.linkedin.com/in/chrisnguyen', 'Twitter Username': '@chrisnguyen', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Design College', 'Gender': 'Non-Binary', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2022-12-20 10:00:00', 'Desired Salary': '75000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterGHI', 'Resume File Id': '5', 'Cover Letter File Id': '', 'Resume File': 'Chris_Nguyen_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '6', 'First Name': 'Emily', 'Last Name': 'Kim', 'Email': 'emily.kim@email.com', 'Phone': '444-555-6666', 'Position': 'Data Architect', 'Status': 'Interview Scheduled', 'Address': '654 Birch St', 'Address 2': '', 'City': 'Townsville', 'State': 'TX', 'Country': 'United States', 'Zip': '34567', 'Available Date': '2023-06-15', 'Website Url': 'https://www.emilykim.com', 'Linkedin Url': 'https://www.linkedin.com/in/emilykim', 'Twitter Username': '@emilykim', 'Education Level': "Master's Degree", 'Education Institution Name': 'Business School', 'Gender': 'Female', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-06-01 12:15:00', 'Desired Salary': '95000', 'Referred By': 'Job board', 'References': 'Previous colleague', 'Source': 'RecruiterJKL', 'Resume File Id': '6', 'Cover Letter File Id': '7', 'Resume File': 'Emily_Kim_Resume.pdf', 'Cover Letter File': 'Emily_Kim_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '7', 'First Name': 'Aaron', 'Last Name': 'Lee', 'Email': 'aaron.lee@email.com', 'Phone': '777-666-5555', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '789 Maple St', 'Address 2': '', 'City': 'Villagetown', 'State': 'CA', 'Country': 'United States', 'Zip': '23456', 'Available Date': '2023-07-01', 'Website Url': 'https://www.aaronlee.com', 'Linkedin Url': 'https://www.linkedin.com/in/aaronlee', 'Twitter Username': '@aaronlee', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Computer Science Institute', 'Gender': 'Male', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-01-10 09:45:00', 'Desired Salary': '85000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterMNO', 'Resume File Id': '7', 'Cover Letter File Id': '', 'Resume File': 'Aaron_Lee_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '8', 'First Name': 'Olivia', 'Last Name': 'Evans', 'Email': 'olivia.evans@email.com', 'Phone': '222-333-4444', 'Position': 'Data Architect', 'Status': 'Offer Extended', 'Address': '', 'Address 2': '', 'City': 'Hometown', 'State': 'NY', 'Country': 'United States', 'Zip': '12345', 'Available Date': '2023-08-15', 'Website Url': 'https://www.oliviaevans.com', 'Linkedin Url': 'https://www.linkedin.com/in/oliviaevans', 'Twitter Username': '@oliviaevans', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Finance University', 'Gender': 'Female', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-08-01 14:30:00', 'Desired Salary': '80000', 'Referred By': 'Job board', 'References': 'Previous employer', 'Source': 'RecruiterPQR', 'Resume File Id': '8', 'Cover Letter File Id': '9', 'Resume File': 'Olivia_Evans_Resume.pdf', 'Cover Letter File': 'Olivia_Evans_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '9', 'First Name': 'James', 'Last Name': 'Miller', 'Email': 'james.miller@email.com', 'Phone': '888-999-0000', 'Position': 'Data Architect', 'Status': 'Rejected', 'Address': '', 'Address 2': '', 'City': 'Techcity', 'State': 'TX', 'Country': 'United States', 'Zip': '56789', 'Available Date': '', 'Website Url': '', 'Linkedin Url': 'https://www.linkedin.com/in/jamesmiller', 'Twitter Username': '@jamesmiller', 'Education Level': 'Associate Degree', 'Education Institution Name': 'Tech College', 'Gender': 'Male', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-09-15 16:00:00', 'Desired Salary': '60000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterSTU', 'Resume File Id': '9', 'Cover Letter File Id': '', 'Resume File': 'James_Miller_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '10', 'First Name': 'Lily', 'Last Name': 'Chen', 'Email': 'lily.chen@email.com', 'Phone': '333-444-5555', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '876 Pine St', 'Address 2': '', 'City': 'Artstown', 'State': 'CA', 'Country': 'United States', 'Zip': '45678', 'Available Date': '2023-10-01', 'Website Url': 'https://www.lilychen.com', 'Linkedin Url': 'https://www.linkedin.com/in/lilychen', 'Twitter Username': '@lilychen', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Art Institute', 'Gender': 'Female', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2022-11-20 11:00:00', 'Desired Salary': '70000', 'Referred By': 'Job board', 'References': 'Previous colleague', 'Source': 'RecruiterVWX', 'Resume File Id': '10', 'Cover Letter File Id': '11', 'Resume File': 'Lily_Chen_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '11', 'First Name': 'David', 'Last Name': 'Johnson', 'Email': 'david.johnson@email.com', 'Phone': '123-234-5678', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '567 Oak St', 'Address 2': '', 'City': 'Techville', 'State': 'CA', 'Country': 'United States', 'Zip': '34567', 'Available Date': '2023-11-01', 'Website Url': 'https://www.davidjohnson.com', 'Linkedin Url': 'https://www.linkedin.com/in/davidjohnson', 'Twitter Username': '@davidjohnson', 'Education Level': "Master's Degree", 'Education Institution Name': 'Engineering College', 'Gender': 'Male', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2022-11-15 13:30:00', 'Desired Salary': '90000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterYZA', 'Resume File Id': '11', 'Cover Letter File Id': '', 'Resume File': 'David_Johnson_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '12', 'First Name': 'Amy', 'Last Name': 'Williams', 'Email': 'amy.williams@email.com', 'Phone': '555-666-7777', 'Position': 'Data Architect', 'Status': 'Interview Scheduled', 'Address': '987 Maple St', 'Address 2': '', 'City': 'Greetown', 'State': 'NY', 'Country': 'United States', 'Zip': '56789', 'Available Date': '2023-12-15', 'Website Url': 'https://www.amywilliams.com', 'Linkedin Url': 'https://www.linkedin.com/in/amywilliams', 'Twitter Username': '@amywilliams', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Computer Science Institute', 'Gender': 'Female', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2022-12-01 10:45:00', 'Desired Salary': '85000', 'Referred By': 'Job board', 'References': 'Previous employer', 'Source': 'RecruiterBCD', 'Resume File Id': '12', 'Cover Letter File Id': '13', 'Resume File': 'Amy_Williams_Resume.pdf', 'Cover Letter File': 'Amy_Williams_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '13', 'First Name': 'Robert', 'Last Name': 'Lee', 'Email': 'robert.lee@email.com', 'Phone': '333-222-1111', 'Position': 'Data Architect', 'Status': 'Rejected', 'Address': '', 'Address 2': '', 'City': 'Marketingtown', 'State': 'CA', 'Country': 'United States', 'Zip': '43210', 'Available Date': '', 'Website Url': '', 'Linkedin Url': 'https://www.linkedin.com/in/robertlee', 'Twitter Username': '@robertlee', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Marketing Institute', 'Gender': 'Male', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2022-12-20 09:30:00', 'Desired Salary': '75000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterEFG', 'Resume File Id': '13', 'Cover Letter File Id': '14', 'Resume File': 'Robert_Lee_Resume.pdf', 'Cover Letter File': 'Robert_Lee_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '14', 'First Name': 'Michelle', 'Last Name': 'Nguyen', 'Email': 'michelle.nguyen@email.com', 'Phone': '777-888-9999', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '876 Oak St', 'Address 2': '', 'City': 'Codecity', 'State': 'TX', 'Country': 'United States', 'Zip': '34567', 'Available Date': '2024-01-01', 'Website Url': 'https://www.michellenguyen.com', 'Linkedin Url': 'https://www.linkedin.com/in/michellenguyen', 'Twitter Username': '@michellenguyen', 'Education Level': "Master's Degree", 'Education Institution Name': 'Engineering College', 'Gender': 'Female', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-01-10 14:00:00', 'Desired Salary': '90000', 'Referred By': 'Job board', 'References': 'Previous colleague', 'Source': 'RecruiterHIJ', 'Resume File Id': '14', 'Cover Letter File Id': '15', 'Resume File': 'Michelle_Nguyen_Resume.pdf', 'Cover Letter File': 'Michelle_Nguyen_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '15', 'First Name': 'Andrew', 'Last Name': 'Smith', 'Email': 'andrew.smith@email.com', 'Phone': '111-222-3333', 'Position': 'Data Architect', 'Status': 'Offer Extended', 'Address': '789 Birch St', 'Address 2': '', 'City': 'Datatown', 'State': 'NY', 'Country': 'United States', 'Zip': '12345', 'Available Date': '2024-01-15', 'Website Url': 'https://www.andrewsmith.com', 'Linkedin Url': 'https://www.linkedin.com/in/andrewsmith', 'Twitter Username': '@andrewsmith', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Data University', 'Gender': 'Male', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2024-04-01 15:45:00', 'Desired Salary': '70000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterKLM', 'Resume File Id': '15', 'Cover Letter File Id': '16', 'Resume File': 'Andrew_Smith_Resume.pdf', 'Cover Letter File': 'Andrew_Smith_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '16', 'First Name': 'Karen', 'Last Name': 'Johnson', 'Email': 'karen.johnson@email.com', 'Phone': '444-555-6666', 'Position': 'Data Architect', 'Status': 'Interview Scheduled', 'Address': '654 Elm St', 'Address 2': '', 'City': 'Marketville', 'State': 'CA', 'Country': 'United States', 'Zip': '45678', 'Available Date': '2024-01-01', 'Website Url': 'https://www.karenjohnson.com', 'Linkedin Url': 'https://www.linkedin.com/in/karenjohnson', 'Twitter Username': '@karenjohnson', 'Education Level': "Master's Degree", 'Education Institution Name': 'Marketing Institute', 'Gender': 'Female', 'Ethnicity': 'Caucasian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-12-01 12:15:00', 'Desired Salary': '60000', 'Referred By': 'Job board', 'References': 'Previous employer', 'Source': 'RecruiterNOP', 'Resume File Id': '16', 'Cover Letter File Id': '17', 'Resume File': 'Karen_Johnson_Resume.pdf', 'Cover Letter File': 'Karen_Johnson_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '17', 'First Name': 'Justin', 'Last Name': 'Kim', 'Email': 'justin.kim@email.com', 'Phone': '999-888-7777', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '876 Pine St', 'Address 2': '', 'City': 'Techtown', 'State': 'TX', 'Country': 'United States', 'Zip': '23456', 'Available Date': '2024-01-15', 'Website Url': 'https://www.justinkim.com', 'Linkedin Url': 'https://www.linkedin.com/in/justinkim', 'Twitter Username': '@justinkim', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Computer Science Institute', 'Gender': 'Male', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2024-01-01 09:45:00', 'Desired Salary': '85000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterQRS', 'Resume File Id': '17', 'Cover Letter File Id': '', 'Resume File': 'Justin_Kim_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '18', 'First Name': 'Grace', 'Last Name': 'Li', 'Email': 'grace.li@email.com', 'Phone': '222-333-4444', 'Position': 'Data Architect', 'Status': 'Rejected', 'Address': '', 'Address 2': '', 'City': 'Dataville', 'State': 'NY', 'Country': 'United States', 'Zip': '56789', 'Available Date': '2024-01-01', 'Website Url': 'https://www.graceli.com', 'Linkedin Url': 'https://www.linkedin.com/in/graceli', 'Twitter Username': '@graceli', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Data University', 'Gender': 'Female', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-05-15 16:00:00', 'Desired Salary': '60000', 'Referred By': 'Job board', 'References': 'Previous colleague', 'Source': 'RecruiterTUV', 'Resume File Id': '18', 'Cover Letter File Id': '', 'Resume File': 'Grace_Li_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '19', 'First Name': 'Christopher', 'Last Name': 'Brown', 'Email': 'christopher.brown@email.com', 'Phone': '888-999-0000', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '', 'Address 2': '', 'City': 'Marketcity', 'State': 'CA', 'Country': 'United States', 'Zip': '12345', 'Available Date': '', 'Website Url': '', 'Linkedin Url': 'https://www.linkedin.com/in/christopherbrown', 'Twitter Username': '@christopherbrown', 'Education Level': "Master's Degree", 'Education Institution Name': 'Marketing Institute', 'Gender': 'Male', 'Ethnicity': 'African American', 'Disability': '', 'Veteran Status': '', 'Application Date': '2023-06-01 11:00:00', 'Desired Salary': '70000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterWXY', 'Resume File Id': '19', 'Cover Letter File Id': '20', 'Resume File': 'Christopher_Brown_Resume.pdf', 'Cover Letter File': 'Christopher_Brown_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '20', 'First Name': 'Isabella', 'Last Name': 'Wang', 'Email': 'isabella.wang@email.com', 'Phone': '333-444-5555', 'Position': 'Data Architect', 'Status': 'Offer Extended', 'Address': '876 Oak St', 'Address 2': '', 'City': 'Codeville', 'State': 'TX', 'Country': 'United States', 'Zip': '45678', 'Available Date': '2024-01-15', 'Website Url': 'https://www.isabellawang.com', 'Linkedin Url': 'https://www.linkedin.com/in/isabellawang', 'Twitter Username': '@isabellawang', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Computer Science Institute', 'Gender': 'Female', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2024-01-01 14:30:00', 'Desired Salary': '90000', 'Referred By': 'Job board', 'References': 'Previous employer', 'Source': 'RecruiterZAB', 'Resume File Id': '20', 'Cover Letter File Id': '21', 'Resume File': 'Isabella_Wang_Resume.pdf', 'Cover Letter File': 'Isabella_Wang_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# {'Candidate Id': '21', 'First Name': 'Justin', 'Last Name': 'Johnson', 'Email': 'justin.kim@email.com', 'Phone': '555-666-7777', 'Position': 'Data Architect', 'Status': 'Pending', 'Address': '987 Pine St', 'Address 2': '', 'City': 'Dataville', 'State': 'CA', 'Country': 'United States', 'Zip': '23456', 'Available Date': '2024-01-01', 'Website Url': 'https://www.marcusjohnson.com', 'Linkedin Url': 'https://www.linkedin.com/in/marcusjohnson', 'Twitter Username': '@marcusjohnson', 'Education Level': "Master's Degree", 'Education Institution Name': 'Engineering College', 'Gender': 'Male', 'Ethnicity': 'African American', 'Disability': '', 'Veteran Status': '', 'Application Date': '2024-01-10 09:45:00', 'Desired Salary': '80000', 'Referred By': 'Employee referral', 'References': 'Available upon request', 'Source': 'RecruiterBCD', 'Resume File Id': '21', 'Cover Letter File Id': '', 'Resume File': 'Marcus_Johnson_Resume.pdf', 'Cover Letter File': '', 'Offer Letter File': ''}
# {'Candidate Id': '22', 'First Name': 'Sophia', 'Last Name': 'Lee', 'Email': 'sophia.lee@email.com', 'Phone': '222-333-4444', 'Position': 'Data Architect', 'Status': 'Rejected', 'Address': '', 'Address 2': '', 'City': 'Marketcity', 'State': 'CA', 'Country': 'United States', 'Zip': '12345', 'Available Date': '', 'Website Url': '', 'Linkedin Url': 'https://www.linkedin.com/in/sophialee', 'Twitter Username': '@sophialee', 'Education Level': "Bachelor's Degree", 'Education Institution Name': 'Marketing Institute', 'Gender': 'Female', 'Ethnicity': 'Asian', 'Disability': '', 'Veteran Status': '', 'Application Date': '2024-01-15 14:00:00', 'Desired Salary': '75000', 'Referred By': 'Job board', 'References': 'Previous colleague', 'Source': 'RecruiterEFG', 'Resume File Id': '22', 'Cover Letter File Id': '23', 'Resume File': 'Sophia_Lee_Resume.pdf', 'Cover Letter File': 'Sophia_Lee_Cover_Letter.pdf', 'Offer Letter File': '', None: ['']}
# Data import CSV file completed.

# %%
import logging
import csv
import json
import requests
import csv
import random


def configure_logging(log_file_path):
    try:
        logging.basicConfig(filename=log_file_path, level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    except FileNotFoundError as e:
        # Log the error to a separate error log file
        error_logger = logging.getLogger('error_logger')
        error_logger.error(f"Error setting up logging: Log file path '{log_file_path}' not found: {e}")
    except PermissionError as e:
        # Log the error to a separate error log file
        error_logger = logging.getLogger('error_logger')
        error_logger.error(f"Error setting up logging: Permission denied for '{log_file_path}': {e}")
    except Exception as e:
        # Log the error to a separate error log file
        error_logger = logging.getLogger('error_logger')
        error_logger.exception("Error setting up logging:")
        # Print a generic error message
        print("An error occurred while setting up logging. Please check the log files for details.")
# initialize.py
import os
import time
# configs.py

# Workable integration token (token)
token = '4pA5n-Ci0iA4o8u_DesrZpzkQxFxBDKkQ9id5klwmqw'

base_url = 'https://assignmentcorporate.workable.com/spi/v3/'

headers = {
    'accept': 'application/json',
    'content-type': 'application/json',
    'Authorization': f'Bearer {token}'
    }

'''
This code initializes logging for the project by creating a timestamped log file.
It first ensures the existence of a directory for log files.
Then, it generates a current timestamp using the time.strftime() function and appends it to the log file name.
Each log file created has a unique name based on the timestamp when the project is run.
Finally, it configures logging using the provided log file path.
'''
# Set up logging with a timestamped log file
log_directory = 'project/logs'
if not os.path.exists(log_directory):
    os.makedirs(log_directory)

current_time = time.strftime("%Y-%m-%d_%H-%M-%S")
log_file_path = os.path.join(log_directory, f'customer_{current_time}.log')  # Unique log file path with timestamp
# if path is wrong file will not be created !
configure_logging(log_file_path)


class CandidateDTO:
    def __init__(self, name, email, phone, address, job, domain, disqualified, sourced):
        self.name = name
        self.email = email
        self.phone = phone
        self.address = address
        self.job = job
        self.domain = domain
        self.disqualified = disqualified
        self.sourced = sourced
    
    def to_json(self):
        """
        Convert the CandidateDTO object to JSON format.
        """
        dto_dict = {
            "name": self.name,
            "email": self.email,
            "phone": self.phone,
            "address": self.address,
            "job": {
                "shortcode": self.job['shortcode'],
                "title": self.job['title']
            },
            "domain": self.domain,
            "disqualified": str(self.disqualified).lower(),  # Convert boolean to lowercase string
            "sourced": str(self.sourced).lower()  # Convert boolean to lowercase string
        }
        return json.dumps(dto_dict, indent=4)

    
class CandidateResponseDTO:
    def __init__(self, id, name, firstname, lastname, headline, image_url, account, job, stage,
                 disqualified, disqualified_at, disqualification_reason, hired_at, sourced,
                 profile_url, address, phone, email, outbound_mailbox, domain, uploader_id,
                 created_at, updated_at, cover_letter, summary, education_entries, experience_entries,
                 skills, answers, resume_url, tags, location, originating_candidate_id):
        self.id = id
        self.name = name
        self.firstname = firstname
        self.lastname = lastname
        self.headline = headline
        self.image_url = image_url
        self.account = account
        self.job = job
        self.stage = stage
        self.disqualified = disqualified
        self.disqualified_at = disqualified_at
        self.disqualification_reason = disqualification_reason
        self.hired_at = hired_at
        self.sourced = sourced
        self.profile_url = profile_url
        self.address = address
        self.phone = phone
        self.email = email
        self.outbound_mailbox = outbound_mailbox
        self.domain = domain
        self.uploader_id = uploader_id
        self.created_at = created_at
        self.updated_at = updated_at
        self.cover_letter = cover_letter
        self.summary = summary
        self.education_entries = education_entries
        self.experience_entries = experience_entries
        self.skills = skills
        self.answers = answers
        self.resume_url = resume_url
        self.tags = tags
        self.location = location
        self.originating_candidate_id = originating_candidate_id

    @classmethod
    def from_json(cls, data):
        candidate_data = data.get('candidate', {})
        return cls(
            id=candidate_data.get('id'),
            name=candidate_data.get('name'),
            firstname=candidate_data.get('firstname'),
            lastname=candidate_data.get('lastname'),
            headline=candidate_data.get('headline'),
            image_url=candidate_data.get('image_url'),
            account=candidate_data.get('account'),
            job=candidate_data.get('job'),
            stage=candidate_data.get('stage'),
            disqualified=candidate_data.get('disqualified'),
            disqualified_at=candidate_data.get('disqualified_at'),
            disqualification_reason=candidate_data.get('disqualification_reason'),
            hired_at=candidate_data.get('hired_at'),
            sourced=candidate_data.get('sourced'),
            profile_url=candidate_data.get('profile_url'),
            address=candidate_data.get('address'),
            phone=candidate_data.get('phone'),
            email=candidate_data.get('email'),
            outbound_mailbox=candidate_data.get('outbound_mailbox'),
            domain=candidate_data.get('domain'),
            uploader_id=candidate_data.get('uploader_id'),
            created_at=candidate_data.get('created_at'),
            updated_at=candidate_data.get('updated_at'),
            cover_letter=candidate_data.get('cover_letter'),
            summary=candidate_data.get('summary'),
            education_entries=candidate_data.get('education_entries'),
            experience_entries=candidate_data.get('experience_entries'),
            skills=candidate_data.get('skills'),
            answers=candidate_data.get('answers'),
            resume_url=candidate_data.get('resume_url'),
            tags=candidate_data.get('tags'),
            location=candidate_data.get('location'),
            originating_candidate_id=candidate_data.get('originating_candidate_id')
        )

class JobsDTO:
    def __init__(self, title, shortcode):
        self.title = title
        self.shortcode = shortcode
        
    def __str__(self):
        return f"Title: {self.title}, Shortcode: {self.shortcode}"
    
logging.info('Script started')
# Read CSV file and return a list of dictionaries
def csv_to_dict_list(file_path):
    try:
        with open(file_path, 'r') as csv_file:
            reader = csv.DictReader(csv_file)
            data = [row for row in reader]
        logging.info('CSV file read successfully.')
        return data
    except Exception as e:
        logging.error(f"Error reading CSV file: {e}")
        return []

# Process each row of data
def process_data(data):
    for row_number, row in enumerate(data, start=1):
        try:
            # Process each row of data here
            logging.info(f"Processed row #{row_number}: {row}")
        except Exception as e:
            logging.error(f"Error processing row #{row_number}: {e}")

def generate_email_suffix(candidate_data):
    first_name = candidate_data['First Name'][0:1].lower()
    last_name = candidate_data['Last Name'][:2].lower()
    email = candidate_data['Email']
    random_integer = str(random.randint(1000, 9999))  # Generate a random integer between 100 and 999
    # Create the email format
    email_format = f"{first_name}{last_name}_{email[:-4]}{random_integer}{email[-4:]}"
    return email_format

def generate_full_address(candidate_data):
    address = candidate_data['Address']
    address_2 = candidate_data['Address 2']
    city = candidate_data['City']
    state = candidate_data['State']
    country = candidate_data['Country']
    zip_code = candidate_data['Zip']
    # Concatenate the address components
    full_address = ', '.join(filter(None, [address, address_2, city, state, country, zip_code]))
    return full_address

def is_disqualified(candidate_data):
    status = candidate_data['Status']
    # Check if the status is 'Rejected'
    disqualified = True if status == 'Rejected' else False
    return disqualified

def position(candidate_data, jobs):
    candidate_position = candidate_data['Position']
    for job in jobs:
        if candidate_position == job.title:
            return {
                "shortcode": job.shortcode,
                "title": job.title
            }
    return None




# Read CSV file and process data
file_path = 'customer_import.csv'
logging.info('Starting data import...')
print('Starting data import...')

csv_data = csv_to_dict_list(file_path)

if csv_data:
    print('CSV file read successfully.')
    logging.info('CSV file read successfully.')
    print('Importing Candidates Information from CSV file...')
    logging.info('Importing Candidates Information from CSV file...')
    process_data(csv_data)
    print('Data import completed.')
    logging.info('Data import completed.')
else:
    print('Error reading CSV file. Please check the log for details.')
    logging.error('Error reading CSV file. Data import aborted.')




# Fetch job data from get jobs request to the API
res = requests.get(base_url + 'jobs', headers=headers)
job_data = res.json()  # Parse JSON response

# Check if the response is successful
if res.status_code == 200:
    jobs = []
    for job in job_data['jobs']:
        # Create JobsDTO object for each job
        job_dto = JobsDTO(
            job['title'],
            job['shortcode'],
        )
        jobs.append(job_dto)

    # # Print the attributes of JobsDTO objects
    # for job in jobs:
    #     print(vars(job))  # Print object attributes as dictionary
else:
    print("Failed to fetch job data:", res.status_code)

# # Log the list of jobs
# logging.info(f"Jobs: {repr([str(job) for job in jobs])}")
logging.info('Creating job objects from given data')
for job in jobs:
    logging.info(vars(job))

# Parse the CSV data and create CandidateDTO objects
candidates = []
for candidate_data in csv_data:
    candidate = CandidateDTO(
        candidate_data['First Name'] + ' ' + candidate_data['Last Name'],
        generate_email_suffix(candidate_data),
        candidate_data['Phone'],
        generate_full_address(candidate_data),
        position(candidate_data, jobs),
        candidate_data['Referred By'],
        is_disqualified(candidate_data),
        sourced=False  # Set sourced to False to prevent email notifications THIS MEANS CANDIDATE APPLIED
    )
    candidates.append(candidate)

logging.info('Creating candidate objects from given data')
# Print the CandidateDTO objects
for candidate in candidates: # Print object attributes as dictionary
    logging.info(f"Candidate: {candidate.name}")




# at this point i have objects of this requested form:

# {
#         "name": "John Doe",
#         "email": "jdo_john.doe@email810.com",
#         "phone": "123-456-7890",
#         "address": "123 Main St, Anytown, CA, United States, 12345",
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "domain": "Employee referral",
#         "disqualified": false,
#         "sourced": false
#     }

logging.info("Importing candidate through POST: %s", candidate.name)

def import_candidate(candidates_data, headers):
    responses = []

    # importing shortcode in the POST url
    url = f'{base_url}jobs/{candidate.job["shortcode"]}/candidates'
    
    candidate_json = candidate.to_json()
    
    # Set response parameters
    response = requests.post(url, candidate_json, headers=headers)
    
    # Check response status
    if response.status_code == 201:
        print(f'Candidate {candidate.name} imported successfully!')
        logging.info(f'Candidate {candidate.name} imported successfully!')
        
        # Response as JSON
        response_json = json.loads(response.text)
        print(json.dumps(response_json, indent=4))
        
        # Convert JSON response to DTO object
        candidate_response = CandidateResponseDTO.from_json(response_json)

        # Print response details
        print(f'Response ID: {candidate_response.id}')
        print(f'Response Name: {candidate_response.name}')
        
        logging.info('Response ID: %s', candidate_response.id)
        logging.info('Response Name: %s', candidate_response.name)

        responses.append(candidate_response)
    else:
        logging.error(f'Failed to import candidate {candidate.name}.')
        print(f'Failed to import candidate {candidate.name}.')
        print('Response:', response.text)
        logging.error('Response: %s', response.text)
        print('Response status:', response.status_code)
        logging.error('Response status: %d', response.status_code)

    return responses









# Prompt the user to select the endpoint
print("Select an endpoint to send a POST request:")
print("1. jobs/{shortcode}/candidates")
print("2. /talent_pool/{stage}/candidates")

choice = input("Enter your choice (1 or 2): ")

if choice == '1':
    print("Importing candidates by POST ...")
    responses = []  # Initialize responses list outside the loop
    for candidate in candidates:
        # Call the import_candidate function for each candidate
        # Extend the responses list with responses for each candidate
        responses += import_candidate(candidates, headers)  # Use += to append the responses
elif choice == '2':
    print("Importing candidates by POST in talent_pool endpoint ...")
    # Add the code for this option if needed
else:
    print("Invalid choice. Please select either 1 or 2.")
# Out:
# Starting data import...
# CSV file read successfully.
# Importing Candidates Information from CSV file...
# Data import completed.
# Select an endpoint to send a POST request:
# 1. jobs/{shortcode}/candidates
# 2. /talent_pool/{stage}/candidates
# Importing candidates by POST ...
# Candidate John Doe imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec934",
#         "name": "John Doe",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:42.143Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880610",
#         "address": "123 Main St, Anytown, CA, United States, 12345",
#         "phone": "123-456-7890",
#         "email": "jdo_john.doe@email4325.com",
#         "outbound_mailbox": "4e3ffvzuvv-d@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:42Z",
#         "updated_at": "2024-01-31T17:26:42Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec934
# Response Name: John Doe
# Candidate Jane Smith imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec939",
#         "name": "Jane Smith",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:44.127Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880615",
#         "address": "456 Oak St, Someville, NY, United States, 56789",
#         "phone": "987-654-3210",
#         "email": "jsm_jane.smith@email7497.com",
#         "outbound_mailbox": "4e3fjzg9twxx@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:44Z",
#         "updated_at": "2024-01-31T17:26:44Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec939
# Response Name: Jane Smith
# Candidate Michael Jones imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec93a",
#         "name": "Michael Jones",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:45.745Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880616",
#         "address": "789 Pine St, Sometown, TX, United States, 67890",
#         "phone": "555-123-4567",
#         "email": "mjo_michael.jones@email3620.com",
#         "outbound_mailbox": "4e3fhp3ntw6n@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:45Z",
#         "updated_at": "2024-01-31T17:26:45Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec93a
# Response Name: Michael Jones
# Candidate Sarah Clark imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec93b",
#         "name": "Sarah Clark",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": true,
#         "disqualified_at": "2024-01-31T17:26:47.067Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880617",
#         "address": "Metroville, CA, United States, 54321",
#         "phone": "111-222-3333",
#         "email": "scl_sarah.clark@email6403.com",
#         "outbound_mailbox": "4e3fjbnroimi@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:47Z",
#         "updated_at": "2024-01-31T17:26:47Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec93b
# Response Name: Sarah Clark
# Candidate Chris Nguyen imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec93e",
#         "name": "Chris Nguyen",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:48.121Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880620",
#         "address": "987 Elm St, Cityville, NY, United States, 45678",
#         "phone": "999-888-7777",
#         "email": "cng_chris.nguyen@email1153.com",
#         "outbound_mailbox": "4e3fm5ow6av1@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:48Z",
#         "updated_at": "2024-01-31T17:26:48Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec93e
# Response Name: Chris Nguyen
# Candidate Emily Kim imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec945",
#         "name": "Emily Kim",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:49.383Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880627",
#         "address": "654 Birch St, Townsville, TX, United States, 34567",
#         "phone": "444-555-6666",
#         "email": "eki_emily.kim@email2037.com",
#         "outbound_mailbox": "4e3fofwpolvk@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:49Z",
#         "updated_at": "2024-01-31T17:26:49Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec945
# Response Name: Emily Kim
# Candidate Aaron Lee imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec951",
#         "name": "Aaron Lee",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:50.940Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880639",
#         "address": "789 Maple St, Villagetown, CA, United States, 23456",
#         "phone": "777-666-5555",
#         "email": "ale_aaron.lee@email5067.com",
#         "outbound_mailbox": "4e3fjuc4o9dh@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:51Z",
#         "updated_at": "2024-01-31T17:26:51Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec951
# Response Name: Aaron Lee
# Candidate Olivia Evans imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec962",
#         "name": "Olivia Evans",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:52.270Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880656",
#         "address": "Hometown, NY, United States, 12345",
#         "phone": "222-333-4444",
#         "email": "oev_olivia.evans@email6485.com",
#         "outbound_mailbox": "4e3frochw0ml@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:52Z",
#         "updated_at": "2024-01-31T17:26:52Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec962
# Response Name: Olivia Evans
# Candidate James Miller imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec972",
#         "name": "James Miller",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": true,
#         "disqualified_at": "2024-01-31T17:26:53.610Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880672",
#         "address": "Techcity, TX, United States, 56789",
#         "phone": "888-999-0000",
#         "email": "jmi_james.miller@email8001.com",
#         "outbound_mailbox": "4e3fwwab4hcq@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:53Z",
#         "updated_at": "2024-01-31T17:26:53Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec972
# Response Name: James Miller
# Candidate Lily Chen imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec97d",
#         "name": "Lily Chen",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:54.701Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880683",
#         "address": "876 Pine St, Artstown, CA, United States, 45678",
#         "phone": "333-444-5555",
#         "email": "lch_lily.chen@email3868.com",
#         "outbound_mailbox": "4e3ffzd7bkod@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:54Z",
#         "updated_at": "2024-01-31T17:26:54Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec97d
# Response Name: Lily Chen
# Candidate David Johnson imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec987",
#         "name": "David Johnson",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:55.826Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880693",
#         "address": "567 Oak St, Techville, CA, United States, 34567",
#         "phone": "123-234-5678",
#         "email": "djo_david.johnson@email7917.com",
#         "outbound_mailbox": "4e3fikrnnugw@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:55Z",
#         "updated_at": "2024-01-31T17:26:55Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec987
# Response Name: David Johnson
# Candidate Amy Williams imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec997",
#         "name": "Amy Williams",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:57.241Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880709",
#         "address": "987 Maple St, Greetown, NY, United States, 56789",
#         "phone": "555-666-7777",
#         "email": "awi_amy.williams@email4092.com",
#         "outbound_mailbox": "4e3fpsp_wj-r@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:57Z",
#         "updated_at": "2024-01-31T17:26:57Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec997
# Response Name: Amy Williams
# Candidate Robert Lee imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9a2",
#         "name": "Robert Lee",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": true,
#         "disqualified_at": "2024-01-31T17:26:58.269Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880720",
#         "address": "Marketingtown, CA, United States, 43210",
#         "phone": "333-222-1111",
#         "email": "rle_robert.lee@email8802.com",
#         "outbound_mailbox": "4e3fteshqsqa@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:58Z",
#         "updated_at": "2024-01-31T17:26:58Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9a2
# Response Name: Robert Lee
# Candidate Michelle Nguyen imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9b2",
#         "name": "Michelle Nguyen",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:26:59.426Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880736",
#         "address": "876 Oak St, Codecity, TX, United States, 34567",
#         "phone": "777-888-9999",
#         "email": "mng_michelle.nguyen@email3117.com",
#         "outbound_mailbox": "4e3fwou9koy3@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:26:59Z",
#         "updated_at": "2024-01-31T17:26:59Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9b2
# Response Name: Michelle Nguyen
# Candidate Andrew Smith imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9bb",
#         "name": "Andrew Smith",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:27:00.547Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880745",
#         "address": "789 Birch St, Datatown, NY, United States, 12345",
#         "phone": "111-222-3333",
#         "email": "asm_andrew.smith@email2238.com",
#         "outbound_mailbox": "4e3fvny4uwik@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:00Z",
#         "updated_at": "2024-01-31T17:27:00Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9bb
# Response Name: Andrew Smith
# Candidate Karen Johnson imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9ca",
#         "name": "Karen Johnson",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:27:02.302Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880760",
#         "address": "654 Elm St, Marketville, CA, United States, 45678",
#         "phone": "444-555-6666",
#         "email": "kjo_karen.johnson@email3478.com",
#         "outbound_mailbox": "4e3f2u4tc03e@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:02Z",
#         "updated_at": "2024-01-31T17:27:02Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9ca
# Response Name: Karen Johnson
# Candidate Justin Kim imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9d7",
#         "name": "Justin Kim",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:27:04.584Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880773",
#         "address": "876 Pine St, Techtown, TX, United States, 23456",
#         "phone": "999-888-7777",
#         "email": "jki_justin.kim@email9691.com",
#         "outbound_mailbox": "4e3fcy3jdi6q@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:04Z",
#         "updated_at": "2024-01-31T17:27:04Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9d7
# Response Name: Justin Kim
# Candidate Grace Li imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9e1",
#         "name": "Grace Li",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": true,
#         "disqualified_at": "2024-01-31T17:27:05.639Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880783",
#         "address": "Dataville, NY, United States, 56789",
#         "phone": "222-333-4444",
#         "email": "gli_grace.li@email8125.com",
#         "outbound_mailbox": "4e3fs8s21ei0@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:05Z",
#         "updated_at": "2024-01-31T17:27:05Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9e1
# Response Name: Grace Li
# Candidate Christopher Brown imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9e9",
#         "name": "Christopher Brown",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:27:06.804Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880791",
#         "address": "Marketcity, CA, United States, 12345",
#         "phone": "888-999-0000",
#         "email": "cbr_christopher.brown@email5789.com",
#         "outbound_mailbox": "4e3f5y_inntg@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:06Z",
#         "updated_at": "2024-01-31T17:27:06Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9e9
# Response Name: Christopher Brown
# Candidate Isabella Wang imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9f4",
#         "name": "Isabella Wang",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:27:07.889Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880802",
#         "address": "876 Oak St, Codeville, TX, United States, 45678",
#         "phone": "333-444-5555",
#         "email": "iwa_isabella.wang@email9282.com",
#         "outbound_mailbox": "4e3fzizho2n5@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:07Z",
#         "updated_at": "2024-01-31T17:27:08Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9f4
# Response Name: Isabella Wang
# Candidate Justin Johnson imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133ec9fa",
#         "name": "Justin Johnson",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": false,
#         "disqualified_at": "2024-01-31T17:27:09.077Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880808",
#         "address": "987 Pine St, Dataville, CA, United States, 23456",
#         "phone": "555-666-7777",
#         "email": "jjo_justin.kim@email1352.com",
#         "outbound_mailbox": "4e3fsmorisoy@outbound.workablemail.com",
#         "domain": "Employee referral",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:09Z",
#         "updated_at": "2024-01-31T17:27:09Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133ec9fa
# Response Name: Justin Johnson
# Candidate Sophia Lee imported successfully!
# {
#     "status": "created",
#     "candidate": {
#         "id": "133eca06",
#         "name": "Sophia Lee",
#         "firstname": null,
#         "lastname": null,
#         "headline": null,
#         "image_url": null,
#         "account": {
#             "subdomain": "assignmentcorporate",
#             "name": "AssignmentCorporate"
#         },
#         "job": {
#             "shortcode": "F8D1EA3849",
#             "title": "Data Architect"
#         },
#         "stage": "Sourced",
#         "disqualified": true,
#         "disqualified_at": "2024-01-31T17:27:10.336Z",
#         "disqualification_reason": null,
#         "hired_at": null,
#         "sourced": true,
#         "profile_url": "https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880820",
#         "address": "Marketcity, CA, United States, 12345",
#         "phone": "222-333-4444",
#         "email": "sle_sophia.lee@email9911.com",
#         "outbound_mailbox": "4e3fhqn6xs2k@outbound.workablemail.com",
#         "domain": "Job board",
#         "uploader_id": null,
#         "created_at": "2024-01-31T17:27:10Z",
#         "updated_at": "2024-01-31T17:27:10Z",
#         "cover_letter": null,
#         "summary": null,
#         "education_entries": [],
#         "experience_entries": [],
#         "skills": [],
#         "answers": [],
#         "resume_url": null,
#         "tags": [],
#         "location": {
#             "location_str": null,
#             "country": null,
#             "country_code": null,
#             "region": null,
#             "region_code": null,
#             "city": null,
#             "zip_code": null
#         },
#         "originating_candidate_id": null
#     }
# }
# Response ID: 133eca06
# Response Name: Sophia Lee

# %%
# Iterate through the list of responses
for index, response in enumerate(responses, start=1):
    print(f"Response {index}:")
    print(f"ID: {response.id}")
    print(f"Name: {response.name}")
    print(f"Firstname: {response.firstname}")
    print(f"Lastname: {response.lastname}")
    # Print other attributes as needed
    print()  # Add a newline for readability between responses
# Out:
# Response 1:
# ID: 133e9a5f
# Name: Sophia Lee
# Firstname: None
# Lastname: None

# %%
responsespool=[]
def import_candidate_to_pool(candidates_data):
    if candidate.sourced:
        stage = "Applied"
    else:
        stage = "Sourced"
    url = f'{base_url}talent_pool/{stage}/candidates'
    print(url)
    print("Importing candidate ",{candidate.name})
    payload = candidate.to_json()
    response = requests.post(url, json=payload, headers=headers)
    # Check response status
    if response.status_code == 201:
        # print(f'Candidate {candidate.name} imported successfully!')
        print(response.text)
        # Response as JSON
        response_json = json.loads(response.text)
        # print(json.dumps(response_json, indent=4))
        
        # # Check Remaining limit
        # remaining_limit = int(response.headers.get('x-rate-limit-remaining', 0)) # If the key 'x-rate-limit-remaining' is not found in the dictionary, the get() method returns the default value, which is 0 in this case.
        # print('Remaining limit:', remaining_limit)
        print(response.status_code)
        responsespool.append(response_json)
    else:
        print(f'Failed to import candidate {candidate.name}.')
        print('Response status:', response.status_code)

print("Importing candidates...")


candidates_json = [candidate.to_json() for candidate in candidates]

# Print the JSON strings for all candidates
for candidate_json in candidates_json:
    # print(candidate_json)
    import_candidate_to_pool(candidate_json)

print(responsespool)
# Out:
# Importing candidates...
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Sophia Lee'}
# {"status":"created","candidate":{"id":"133e4043","name":"Uploaded Candidate","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":null,"disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322845553","address":null,"phone":null,"email":null,"outbound_mailbox":"4e3fu_pwmdgn@outbound.workablemail.com","domain":null,"uploader_id":null,"created_at":"2024-01-31T15:40:32Z","updated_at":"2024-01-31T15:40:32Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# 201
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Sophia Lee'}
# {"status":"created","candidate":{"id":"133e404a","name":"Uploaded Candidate","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":null,"disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322845560","address":null,"phone":null,"email":null,"outbound_mailbox":"4e3f2rojoccu@outbound.workablemail.com","domain":null,"uploader_id":null,"created_at":"2024-01-31T15:40:33Z","updated_at":"2024-01-31T15:40:33Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# 201
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Sophia Lee'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 37
#      34 # Print the JSON strings for all candidates
#      35 for candidate_json in candidates_json:
#      36     # print(candidate_json)
# ---> 37     import_candidate_to_pool(candidate_json)
#      39 print(responsespool)
#
# Cell In[9], line 11, in import_candidate_to_pool(candidates_data)
#       9 print("Importing candidate ",{candidate.name})
#      10 payload = candidate.to_json()
# ---> 11 response = requests.post(url, json=payload, headers=headers)
#      12 # Check response status
#      13 if response.status_code == 201:
#      14     # print(f'Candidate {candidate.name} imported successfully!')
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
responsespool=[]
def import_candidate_to_pool(candidates_data):
    if candidate.sourced:
        stage = "Applied"
    else:
        stage = "Sourced"
    url = f'https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates'
    print(url)
    print("Importing candidate ",{candidate.name})
    payload = candidate.to_json()
    headers = {'Content-Type': 'application/json',
               'Authorization': f'Bearer {token}',
               'Accept': 'application/json',
               'stage': 'Sourced'
                    }
    
    response = requests.post(url, json=payload, headers=headers)
    
    if response.status_code == 201:

        print(response.text)

        response_json = json.loads(response.text)

        print(response.status_code)
        responsespool.append(response_json)
    else:
        print(f'Failed to import candidate {candidate.name}.')
        print('Response status:', response.status_code)

print("Importing candidates by POST ...")
for candidate in candidates:
    import_candidate_to_pool(candidate)
# Out:
# Importing candidates by POST ...
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'John Doe'}
# {"status":"created","candidate":{"id":"133e7b1c","name":"Uploaded Candidate","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":null,"disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322860618","address":null,"phone":null,"email":null,"outbound_mailbox":"4e3f8mciqnia@outbound.workablemail.com","domain":null,"uploader_id":null,"created_at":"2024-01-31T16:26:26Z","updated_at":"2024-01-31T16:26:26Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# 201
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Jane Smith'}
# {"status":"created","candidate":{"id":"133e7b23","name":"Uploaded Candidate","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":null,"disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322860625","address":null,"phone":null,"email":null,"outbound_mailbox":"4e3f-jxlerik@outbound.workablemail.com","domain":null,"uploader_id":null,"created_at":"2024-01-31T16:26:27Z","updated_at":"2024-01-31T16:26:27Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# 201
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Michael Jones'}
# {"status":"created","candidate":{"id":"133e7b28","name":"Uploaded Candidate","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":null,"disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322860630","address":null,"phone":null,"email":null,"outbound_mailbox":"4e3fil5yxee8@outbound.workablemail.com","domain":null,"uploader_id":null,"created_at":"2024-01-31T16:26:28Z","updated_at":"2024-01-31T16:26:28Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# 201
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Sarah Clark'}
# {"status":"created","candidate":{"id":"133e7b2e","name":"Uploaded Candidate","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":null,"disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322860636","address":null,"phone":null,"email":null,"outbound_mailbox":"4e3f78yzhv-s@outbound.workablemail.com","domain":null,"uploader_id":null,"created_at":"2024-01-31T16:26:29Z","updated_at":"2024-01-31T16:26:29Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# 201
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Chris Nguyen'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 33
#      31 print("Importing candidates by POST ...")
#      32 for candidate in candidates:
# ---> 33     import_candidate_to_pool(candidate)
#
# Cell In[64], line 17, in import_candidate_to_pool(candidates_data)
#      10 payload = candidate.to_json()
#      11 headers = {'Content-Type': 'application/json',
#      12            'Authorization': f'Bearer {token}',
#      13            'Accept': 'application/json',
#      14            'stage': 'Sourced'
#      15                 }
# ---> 17 response = requests.post(url, json=payload, headers=headers)
#      19 if response.status_code == 201:
#      21     print(response.text)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\anje1o\miniconda3\envs\boom\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def import_candidate_to_pool(candidates_data, headers):
    responsespool=[]
    if candidate.sourced:
        stage = "Applied"
    else:
        stage = "Sourced"
    url = f'{base_url}talent_pool/{stage}/candidates'
    print(url)
    print("Importing candidate ",{candidate.name})
    payload = candidate.to_json()
    response = requests.post(url, payload, headers=headers)

    if response.status_code == 201:
        print("Candidate", candidate.name, "imported successfully!")
        print(response.text)
        responsespool.append(json.loads(response.text))
    else:
        print(f'Failed to import candidate {candidate.name}.')
        print('Response status:', response.status_code)

    return responsespool

print("Importing candidates by POST ...")

for candidate in candidates:
    import_candidate_to_pool(candidate, headers)
# Out:
# Importing candidates by POST ...
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'John Doe'}
# Candidate John Doe imported successfully!
# {"status":"created","candidate":{"id":"133e8326","name":"John Doe","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:04.243Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862676","address":"123 Main St, Anytown, CA, United States, 12345","phone":"123-456-7890","email":"jdo_john.doe@email4446.com","outbound_mailbox":"4e3fiq8ba5yt@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:04Z","updated_at":"2024-01-31T16:33:04Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Jane Smith'}
# Candidate Jane Smith imported successfully!
# {"status":"created","candidate":{"id":"133e832b","name":"Jane Smith","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:05.259Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862681","address":"456 Oak St, Someville, NY, United States, 56789","phone":"987-654-3210","email":"jsm_jane.smith@email5306.com","outbound_mailbox":"4e3fpnj7tyjr@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:05Z","updated_at":"2024-01-31T16:33:05Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Michael Jones'}
# Candidate Michael Jones imported successfully!
# {"status":"created","candidate":{"id":"133e8334","name":"Michael Jones","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:06.325Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862690","address":"789 Pine St, Sometown, TX, United States, 67890","phone":"555-123-4567","email":"mjo_michael.jones@email7711.com","outbound_mailbox":"4e3flmmhnsio@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:06Z","updated_at":"2024-01-31T16:33:06Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Sarah Clark'}
# Candidate Sarah Clark imported successfully!
# {"status":"created","candidate":{"id":"133e833c","name":"Sarah Clark","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":true,"disqualified_at":"2024-01-31T16:33:07.557Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862698","address":"Metroville, CA, United States, 54321","phone":"111-222-3333","email":"scl_sarah.clark@email2673.com","outbound_mailbox":"4e3fzbo0i9l5@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:07Z","updated_at":"2024-01-31T16:33:07Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Chris Nguyen'}
# Candidate Chris Nguyen imported successfully!
# {"status":"created","candidate":{"id":"133e8343","name":"Chris Nguyen","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:08.614Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862705","address":"987 Elm St, Cityville, NY, United States, 45678","phone":"999-888-7777","email":"cng_chris.nguyen@email5007.com","outbound_mailbox":"4e3faaivzfxi@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:08Z","updated_at":"2024-01-31T16:33:08Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Emily Kim'}
# Candidate Emily Kim imported successfully!
# {"status":"created","candidate":{"id":"133e834c","name":"Emily Kim","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:09.611Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862714","address":"654 Birch St, Townsville, TX, United States, 34567","phone":"444-555-6666","email":"eki_emily.kim@email9904.com","outbound_mailbox":"4e3fpegkwsf6@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:09Z","updated_at":"2024-01-31T16:33:09Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Aaron Lee'}
# Candidate Aaron Lee imported successfully!
# {"status":"created","candidate":{"id":"133e8353","name":"Aaron Lee","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:10.677Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862721","address":"789 Maple St, Villagetown, CA, United States, 23456","phone":"777-666-5555","email":"ale_aaron.lee@email7824.com","outbound_mailbox":"4e3fottmbhti@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:10Z","updated_at":"2024-01-31T16:33:10Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Olivia Evans'}
# Candidate Olivia Evans imported successfully!
# {"status":"created","candidate":{"id":"133e835e","name":"Olivia Evans","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:11.723Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862732","address":"Hometown, NY, United States, 12345","phone":"222-333-4444","email":"oev_olivia.evans@email3841.com","outbound_mailbox":"4e3fmnf9y-vo@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:11Z","updated_at":"2024-01-31T16:33:11Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'James Miller'}
# Candidate James Miller imported successfully!
# {"status":"created","candidate":{"id":"133e8366","name":"James Miller","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":true,"disqualified_at":"2024-01-31T16:33:12.878Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862740","address":"Techcity, TX, United States, 56789","phone":"888-999-0000","email":"jmi_james.miller@email3033.com","outbound_mailbox":"4e3fzzv6ge4i@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:12Z","updated_at":"2024-01-31T16:33:13Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Lily Chen'}
# Candidate Lily Chen imported successfully!
# {"status":"created","candidate":{"id":"133e836c","name":"Lily Chen","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:13.901Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862746","address":"876 Pine St, Artstown, CA, United States, 45678","phone":"333-444-5555","email":"lch_lily.chen@email6214.com","outbound_mailbox":"4e3fpiljpxc-@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:13Z","updated_at":"2024-01-31T16:33:14Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'David Johnson'}
# Candidate David Johnson imported successfully!
# {"status":"created","candidate":{"id":"133e8372","name":"David Johnson","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:14.940Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862752","address":"567 Oak St, Techville, CA, United States, 34567","phone":"123-234-5678","email":"djo_david.johnson@email1087.com","outbound_mailbox":"4e3fsjlcjc39@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:15Z","updated_at":"2024-01-31T16:33:15Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Amy Williams'}
# Candidate Amy Williams imported successfully!
# {"status":"created","candidate":{"id":"133e8378","name":"Amy Williams","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:15.950Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862758","address":"987 Maple St, Greetown, NY, United States, 56789","phone":"555-666-7777","email":"awi_amy.williams@email6685.com","outbound_mailbox":"4e3fq5z_rvdf@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:16Z","updated_at":"2024-01-31T16:33:16Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Robert Lee'}
# Candidate Robert Lee imported successfully!
# {"status":"created","candidate":{"id":"133e8386","name":"Robert Lee","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":true,"disqualified_at":"2024-01-31T16:33:17.072Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862772","address":"Marketingtown, CA, United States, 43210","phone":"333-222-1111","email":"rle_robert.lee@email9621.com","outbound_mailbox":"4e3fco6rgzaf@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:17Z","updated_at":"2024-01-31T16:33:17Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Michelle Nguyen'}
# Candidate Michelle Nguyen imported successfully!
# {"status":"created","candidate":{"id":"133e838c","name":"Michelle Nguyen","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:18.155Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862778","address":"876 Oak St, Codecity, TX, United States, 34567","phone":"777-888-9999","email":"mng_michelle.nguyen@email8141.com","outbound_mailbox":"4e3fz17pbyji@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:18Z","updated_at":"2024-01-31T16:33:18Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Andrew Smith'}
# Candidate Andrew Smith imported successfully!
# {"status":"created","candidate":{"id":"133e8392","name":"Andrew Smith","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:19.241Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862784","address":"789 Birch St, Datatown, NY, United States, 12345","phone":"111-222-3333","email":"asm_andrew.smith@email3574.com","outbound_mailbox":"4e3fpe-af7gw@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:19Z","updated_at":"2024-01-31T16:33:19Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Karen Johnson'}
# Candidate Karen Johnson imported successfully!
# {"status":"created","candidate":{"id":"133e8397","name":"Karen Johnson","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:20.293Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862789","address":"654 Elm St, Marketville, CA, United States, 45678","phone":"444-555-6666","email":"kjo_karen.johnson@email4863.com","outbound_mailbox":"4e3f5qvewu7h@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:20Z","updated_at":"2024-01-31T16:33:20Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Justin Kim'}
# Candidate Justin Kim imported successfully!
# {"status":"created","candidate":{"id":"133e839f","name":"Justin Kim","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:21.290Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862797","address":"876 Pine St, Techtown, TX, United States, 23456","phone":"999-888-7777","email":"jki_justin.kim@email5362.com","outbound_mailbox":"4e3futsdf1wt@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:21Z","updated_at":"2024-01-31T16:33:21Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Grace Li'}
# Candidate Grace Li imported successfully!
# {"status":"created","candidate":{"id":"133e83a9","name":"Grace Li","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":true,"disqualified_at":"2024-01-31T16:33:22.438Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862807","address":"Dataville, NY, United States, 56789","phone":"222-333-4444","email":"gli_grace.li@email9331.com","outbound_mailbox":"4e3fvukrv7wp@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:22Z","updated_at":"2024-01-31T16:33:22Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Christopher Brown'}
# Candidate Christopher Brown imported successfully!
# {"status":"created","candidate":{"id":"133e83b2","name":"Christopher Brown","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:23.557Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862816","address":"Marketcity, CA, United States, 12345","phone":"888-999-0000","email":"cbr_christopher.brown@email1096.com","outbound_mailbox":"4e3frsytep8v@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:23Z","updated_at":"2024-01-31T16:33:23Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Isabella Wang'}
# Candidate Isabella Wang imported successfully!
# {"status":"created","candidate":{"id":"133e83b9","name":"Isabella Wang","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:24.574Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862823","address":"876 Oak St, Codeville, TX, United States, 45678","phone":"333-444-5555","email":"iwa_isabella.wang@email8376.com","outbound_mailbox":"4e3fy0j2tfug@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:24Z","updated_at":"2024-01-31T16:33:24Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Justin Johnson'}
# Candidate Justin Johnson imported successfully!
# {"status":"created","candidate":{"id":"133e83be","name":"Justin Johnson","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T16:33:25.594Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862828","address":"987 Pine St, Dataville, CA, United States, 23456","phone":"555-666-7777","email":"jjo_justin.kim@email9085.com","outbound_mailbox":"4e3ffk4hdgtx@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T16:33:25Z","updated_at":"2024-01-31T16:33:25Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}
# https://assignmentcorporate.workable.com/spi/v3/talent_pool/Sourced/candidates
# Importing candidate  {'Sophia Lee'}
# Candidate Sophia Lee imported successfully!
# {"status":"created","candidate":{"id":"133e83c1","name":"Sophia Lee","firstname":null,"lastname":null,"headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"talent_pool":{"talent_pool_id":636744},"stage":"Sourced","disqualified":true,"disqualified_at":"2024-01-31T16:33:26.633Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/talent_pool/browser/sourced/candidate/322862831","address":"Marketcity, CA, United States, 12345","phone":"222-333-4444","email":"sle_sophia.lee@email2783.com","outbound_mailbox":"4e3fw_j5wlli@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T16:33:26Z","updated_at":"2024-01-31T16:33:26Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":null,"country":null,"country_code":null,"region":null,"region_code":null,"city":null,"zip_code":null},"originating_candidate_id":null}}

# %%
print(responses)
# Out:
# [<__main__.CandidateResponseDTO object at 0x000001F7694FF460>]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 3
#       1 # Iterate through the list of responses
#       2 for index, response in enumerate(responses, start=1):
# ----> 3     candidate = response['candidate']
#       4     job = candidate['job']  # Access the job dictionary
#       6     # Print candidate details with numbers next to names
#
# TypeError: 'CandidateResponseDTO' object is not subscriptable

# %%
# Iterate through the list of responses
for index, response in enumerate(responses, start=1):
    # Access the attributes of the CandidateResponseDTO object directly
    id = response.id
    name = response.name
    job_shortcode = response.job.shortcode if response.job else "N/A"  # Example: Accessing job shortcode if it exists

    # Print candidate details with numbers next to names
    logging.info(f"{index}. Name: {name}, ID: {id}, Job Shortcode: {job_shortcode}")

# Ask the user to input a number corresponding to a candidate
selected_number = input("Enter the number corresponding to your choice: ")

# Validate the user input and retrieve the selected candidate details
try:
    selected_index = int(selected_number)
    if 1 <= selected_index <= len(responses):
        selected_candidate = responses[selected_index - 1]
        selected_id = selected_candidate.id
        selected_job_title = selected_candidate.job.title if selected_candidate.job else "N/A"  # Example: Accessing job title if it exists
        logging.info(f"You selected Candidate ID: {selected_id}, Job Title: {selected_job_title}")
    else:
        logging.error("Invalid input: Please enter a number within the given range.")
except ValueError:
    logging.error("Invalid input: Please enter a valid number.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 6
#       4 id = response.id
#       5 name = response.name
# ----> 6 job_shortcode = response.job.shortcode if response.job else "N/A"  # Example: Accessing job shortcode if it exists
#       8 # Print candidate details with numbers next to names
#       9 logging.info(f"{index}. Name: {name}, ID: {id}, Job Shortcode: {job_shortcode}")
#
# AttributeError: 'dict' object has no attribute 'shortcode'

# %% [markdown]
# EDW VRISKOMAi

# %%
# Iterate through the list of responses
for index, response in enumerate(responses, start=1):
    # Access the attributes of the CandidateResponseDTO object directly
    id = response.id
    name = response.name
    job_shortcode = response.job['shortcode'] if response.job else "N/A"

    # Print candidate details with numbers next to names
    print(f"{index}. Name: {name}, ID: {id}, Job Shortcode: {job_shortcode}")

# Ask the user to input a number corresponding to a candidate
selected_number = input("Enter the number corresponding to your choice: ")

# Validate the user input and retrieve the selected candidate details
try:
    selected_index = int(selected_number)
    if 1 <= selected_index <= len(responses):
        selected_candidate = responses[selected_index - 1]
        selected_id = selected_candidate.id
        selected_shortcode = selected_candidate.job['shortcode']
        print(f"You selected Candidate {selected_index}. ID: {selected_id}, Shortcode: {selected_shortcode}")
    else:
        print("Invalid input: Please enter a number within the given range.")
except ValueError:
    print("Invalid input: Please enter a valid number.")



id =selected_id
shortcode = selected_shortcode

# Get request based on {id}
def get_candidate_info(base_url, id, token):
    
    url = f'{base_url}candidates/{id}' # url = f'{base_url}{shortcode}/candidates/{id}'
    print("URL:", url)
    try:
        # Send the GET request
        response = requests.get(url, headers=headers)
        
        # Check the response status code
        if response.status_code == 200:
            print("Response:")
            print(response.text)
        else:
            print(f"Error: {response.status_code} - {response.reason}")
    except requests.exceptions.RequestException as e:
        print("Error:", e)

def print_candidate_data_by_id(responses, desired_ids):
    # Iterate through each candidate response object in the responses list
    for candidate_response in responses:
        # Check if the candidate's ID is in the desired IDs list
        if candidate_response.id in desired_ids:
            # Print the candidate data
            print({
                'id': candidate_response.id,
                'name': candidate_response.name,
                'firstname': candidate_response.firstname,
                'lastname': candidate_response.lastname,
                'headline': candidate_response.headline,
                'image_url': candidate_response.image_url,
                'account': candidate_response.account,
                'job': candidate_response.job,
                'stage': candidate_response.stage,
                'disqualified': candidate_response.disqualified,
                'disqualified_at': candidate_response.disqualified_at,
                'disqualification_reason': candidate_response.disqualification_reason,
                'hired_at': candidate_response.hired_at,
                'sourced': candidate_response.sourced,
                'profile_url': candidate_response.profile_url,
                'address': candidate_response.address,
                'phone': candidate_response.phone,
                'email': candidate_response.email,
                'outbound_mailbox': candidate_response.outbound_mailbox,
                'domain': candidate_response.domain,
                'uploader_id': candidate_response.uploader_id,
                'created_at': candidate_response.created_at,
                'updated_at': candidate_response.updated_at,
                'cover_letter': candidate_response.cover_letter,
                'summary': candidate_response.summary,
                'education_entries': candidate_response.education_entries,
                'experience_entries': candidate_response.experience_entries,
                'skills': candidate_response.skills,
                'answers': candidate_response.answers,
                'resume_url': candidate_response.resume_url,
                'tags': candidate_response.tags,
                'location': candidate_response.location,
                'originating_candidate_id': candidate_response.originating_candidate_id
            })


print("Choose an option:")
print("1. Perform a GET request using the API")
print("2. Print candidate data locally")
choice = input("Enter your choice (1 or 2): ")

if choice == '1':
    get_candidate_info(base_url, id, token)
elif choice == '2':
    print_candidate_data_by_id(responses, id)
else:
    print("Invalid choice. Please enter 1 or 2.")
# Out:
# 1. Name: John Doe, ID: 133ec934, Job Shortcode: F8D1EA3849
# 2. Name: Jane Smith, ID: 133ec939, Job Shortcode: F8D1EA3849
# 3. Name: Michael Jones, ID: 133ec93a, Job Shortcode: F8D1EA3849
# 4. Name: Sarah Clark, ID: 133ec93b, Job Shortcode: F8D1EA3849
# 5. Name: Chris Nguyen, ID: 133ec93e, Job Shortcode: F8D1EA3849
# 6. Name: Emily Kim, ID: 133ec945, Job Shortcode: F8D1EA3849
# 7. Name: Aaron Lee, ID: 133ec951, Job Shortcode: F8D1EA3849
# 8. Name: Olivia Evans, ID: 133ec962, Job Shortcode: F8D1EA3849
# 9. Name: James Miller, ID: 133ec972, Job Shortcode: F8D1EA3849
# 10. Name: Lily Chen, ID: 133ec97d, Job Shortcode: F8D1EA3849
# 11. Name: David Johnson, ID: 133ec987, Job Shortcode: F8D1EA3849
# 12. Name: Amy Williams, ID: 133ec997, Job Shortcode: F8D1EA3849
# 13. Name: Robert Lee, ID: 133ec9a2, Job Shortcode: F8D1EA3849
# 14. Name: Michelle Nguyen, ID: 133ec9b2, Job Shortcode: F8D1EA3849
# 15. Name: Andrew Smith, ID: 133ec9bb, Job Shortcode: F8D1EA3849
# 16. Name: Karen Johnson, ID: 133ec9ca, Job Shortcode: F8D1EA3849
# 17. Name: Justin Kim, ID: 133ec9d7, Job Shortcode: F8D1EA3849
# 18. Name: Grace Li, ID: 133ec9e1, Job Shortcode: F8D1EA3849
# 19. Name: Christopher Brown, ID: 133ec9e9, Job Shortcode: F8D1EA3849
# 20. Name: Isabella Wang, ID: 133ec9f4, Job Shortcode: F8D1EA3849
# 21. Name: Justin Johnson, ID: 133ec9fa, Job Shortcode: F8D1EA3849
# 22. Name: Sophia Lee, ID: 133eca06, Job Shortcode: F8D1EA3849
# You selected Candidate 2. ID: 133ec939, Shortcode: F8D1EA3849
# Choose an option:
# 1. Perform a GET request using the API
# 2. Print candidate data locally
# URL: https://assignmentcorporate.workable.com/spi/v3/candidates/133ec939
# Response:
# {"candidate":{"id":"133ec939","name":"Jane Smith","firstname":"Jane","lastname":"Smith","headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"job":{"shortcode":"F8D1EA3849","title":"Data Architect"},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T17:26:44.127Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880615","address":"456 Oak St, Someville, NY, United States, 56789","phone":"987-654-3210","email":"jsm_jane.smith@email7497.com","outbound_mailbox":"4e3fjzg9twxx@outbound.workablemail.com","domain":"Job board","uploader_id":null,"created_at":"2024-01-31T17:26:44Z","updated_at":"2024-01-31T17:30:03Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":"Somerville, New York, United States","country":"United States","country_code":"US","region":"New York","region_code":"New York","city":"Somerville","zip_code":null},"originating_candidate_id":null}}

# %%
# Iterate through the list of responses
for index, response in enumerate(responses, start=1):
    # Access the attributes of the CandidateResponseDTO object directly
    id = response.id
    name = response.name
    job_shortcode = response.job['shortcode'] if response.job else "N/A"

    # Print candidate details with numbers next to names
    print(f"{index}. Name: {name}, ID: {id}, Job Shortcode: {job_shortcode}")

# Ask the user to input a number corresponding to a candidate
selected_number = input("Enter the number corresponding to your choice: ")

# Validate the user input and retrieve the selected candidate details
try:
    selected_index = int(selected_number)
    if 1 <= selected_index <= len(responses):
        selected_candidate = responses[selected_index - 1]
        selected_id = selected_candidate.id
        #selected_shortcode = selected_candidate.job['shortcode']
        print(f"You selected Candidate {selected_index}. ID: {selected_id}, Shortcode: {selected_shortcode}")
    else:
        print("Invalid input: Please enter a number within the given range.")
except ValueError:
    print("Invalid input: Please enter a valid number.")



id =selected_id
#shortcode = selected_shortcode

# Get request based on {id}
def get_candidate_info(base_url, id, token):
    
    url = f'{base_url}candidates/{id}' # url = f'{base_url}{shortcode}/candidates/{id}'
    print("URL:", url)
    try:
        # Send the GET request
        response = requests.get(url, headers=headers)
        
        # Check the response status code
        if response.status_code == 200:
            print("Response:")
            print(response.text)
        else:
            print(f"Error: {response.status_code} - {response.reason}")
    except requests.exceptions.RequestException as e:
        print("Error:", e)

search_candidate_by_id = lambda responses, id: next((response.__dict__ for response in responses if response.id == id), None)


print("Choose an option:")
print("1. Perform a GET request using the API")
print("2. Print candidate data locally")
choice = input("Enter your choice (1 or 2): ")

if choice == '1':
    get_candidate_info(base_url, selected_id, token)
elif choice == '2':
    
    candidate_data = search_candidate_by_id(responses, selected_id)
    print(candidate_data)
else:
    print("Invalid choice. Please enter 1 or 2.")
# Out:
# 1. Name: John Doe, ID: 133ec934, Job Shortcode: F8D1EA3849
# 2. Name: Jane Smith, ID: 133ec939, Job Shortcode: F8D1EA3849
# 3. Name: Michael Jones, ID: 133ec93a, Job Shortcode: F8D1EA3849
# 4. Name: Sarah Clark, ID: 133ec93b, Job Shortcode: F8D1EA3849
# 5. Name: Chris Nguyen, ID: 133ec93e, Job Shortcode: F8D1EA3849
# 6. Name: Emily Kim, ID: 133ec945, Job Shortcode: F8D1EA3849
# 7. Name: Aaron Lee, ID: 133ec951, Job Shortcode: F8D1EA3849
# 8. Name: Olivia Evans, ID: 133ec962, Job Shortcode: F8D1EA3849
# 9. Name: James Miller, ID: 133ec972, Job Shortcode: F8D1EA3849
# 10. Name: Lily Chen, ID: 133ec97d, Job Shortcode: F8D1EA3849
# 11. Name: David Johnson, ID: 133ec987, Job Shortcode: F8D1EA3849
# 12. Name: Amy Williams, ID: 133ec997, Job Shortcode: F8D1EA3849
# 13. Name: Robert Lee, ID: 133ec9a2, Job Shortcode: F8D1EA3849
# 14. Name: Michelle Nguyen, ID: 133ec9b2, Job Shortcode: F8D1EA3849
# 15. Name: Andrew Smith, ID: 133ec9bb, Job Shortcode: F8D1EA3849
# 16. Name: Karen Johnson, ID: 133ec9ca, Job Shortcode: F8D1EA3849
# 17. Name: Justin Kim, ID: 133ec9d7, Job Shortcode: F8D1EA3849
# 18. Name: Grace Li, ID: 133ec9e1, Job Shortcode: F8D1EA3849
# 19. Name: Christopher Brown, ID: 133ec9e9, Job Shortcode: F8D1EA3849
# 20. Name: Isabella Wang, ID: 133ec9f4, Job Shortcode: F8D1EA3849
# 21. Name: Justin Johnson, ID: 133ec9fa, Job Shortcode: F8D1EA3849
# 22. Name: Sophia Lee, ID: 133eca06, Job Shortcode: F8D1EA3849
# You selected Candidate 1. ID: 133ec934, Shortcode: F8D1EA3849
# Choose an option:
# 1. Perform a GET request using the API
# 2. Print candidate data locally
# URL: https://assignmentcorporate.workable.com/spi/v3/candidates/133ec934
# Response:
# {"candidate":{"id":"133ec934","name":"John Doe","firstname":"John","lastname":"Doe","headline":null,"image_url":null,"account":{"subdomain":"assignmentcorporate","name":"AssignmentCorporate"},"job":{"shortcode":"F8D1EA3849","title":"Data Architect"},"stage":"Sourced","disqualified":false,"disqualified_at":"2024-01-31T17:26:42.143Z","disqualification_reason":null,"hired_at":null,"sourced":true,"profile_url":"https://assignmentcorporate.workable.com/backend/jobs/3723929/candidates/322880610","address":"123 Main St, Anytown, CA, United States, 12345","phone":"123-456-7890","email":"jdo_john.doe@email4325.com","outbound_mailbox":"4e3ffvzuvv-d@outbound.workablemail.com","domain":"Employee referral","uploader_id":null,"created_at":"2024-01-31T17:26:42Z","updated_at":"2024-01-31T17:30:19Z","cover_letter":null,"summary":null,"education_entries":[],"experience_entries":[],"skills":[],"answers":[],"resume_url":null,"tags":[],"location":{"location_str":"California, United States","country":"United States","country_code":"US","region":"California","region_code":"California","city":null,"zip_code":null},"originating_candidate_id":null}}

# %%
responses += import_candidate(candidates, headers)  # Use += to append the responses

# %%
# Iterate through the list of responses
for index, response in enumerate(responses, start=1):
    candidate = response['candidate']
    job = candidate['job']  # Access the job dictionary
    
    # Print candidate details with numbers next to names
    print(f"{index}. Name: {candidate['name']}, ID: {candidate['id']}, Job Title: {job['title']}, Shortcode: {job['shortcode']}")

# Ask the user to input a number corresponding to a candidate
selected_number = input("Enter the number corresponding to your choice: ")

# Validate the user input and retrieve the selected candidate details
try:
    selected_index = int(selected_number)
    if 1 <= selected_index <= len(responses):
        selected_candidate = responses[selected_index - 1]['candidate']
        selected_id = selected_candidate['id']
        selected_shortcode = selected_candidate['job']['shortcode']
        print(f"You selected Candidate ID: {selected_id}, Shortcode: {selected_shortcode}")
    else:
        print("Invalid input: Please enter a number within the given range.")
except ValueError:
    print("Invalid input: Please enter a valid number.")

id =selected_id
shortcode = selected_shortcode

headers = {
'accept': 'application/json',
'Content-Type': 'application/json',
'Authorization': f'Bearer {token}'
}

# Get request based on {id}
def get_candidate_info(base_url, id, token):
    
    url = f'{base_url}candidates/{id}' # url = f'{base_url}{shortcode}/candidates/{id}'
    print("URL:", url)
    try:
        # Send the GET request
        response = requests.get(url, headers=headers)
        
        # Check the response status code
        if response.status_code == 200:
            print("Response:")
            print(response.text)
        else:
            print(f"Error: {response.status_code} - {response.reason}")
    except requests.exceptions.RequestException as e:
        print("Error:", e)

# Get request from responses DTO based on {id}
def print_candidate_data_by_id(responses, desired_ids):
    # Iterate through each candidate dictionary in the responses list
    for candidate_info in responses:
        # Extract the "candidate" part from the candidate dictionary
        candidate_data = candidate_info.get('candidate')
        if candidate_data and candidate_data.get('id') in desired_ids:
            # Print the candidate data
            print({'candidate': candidate_data})

print("Choose an option:")
print("1. Perform a GET request using the API")
print("2. Print candidate data locally")
choice = input("Enter your choice (1 or 2): ")

if choice == '1':
    get_candidate_info(base_url, id, token)
elif choice == '2':
    print_candidate_data_by_id(responses, id)
else:
    print("Invalid choice. Please enter 1 or 2.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 9
#       6     job_shortcode = response.job['shortcode'] if response.job else "N/A"
#       8     # Print candidate details with numbers next to names
# ----> 9     print(f"{index}. Name: {candidate['name']}, ID: {candidate['id']}, Job Title: {job['title']}, Shortcode: {job['shortcode']}")
#      11 # Ask the user to input a number corresponding to a candidate
#      12 selected_number = input("Enter the number corresponding to your choice: ")
#
# TypeError: 'CandidateDTO' object is not subscriptable
